# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("./mnist/data/", one_hot=True)
# Out:
# Extracting ./mnist/data/train-images-idx3-ubyte.gz
# Extracting ./mnist/data/train-labels-idx1-ubyte.gz
# Extracting ./mnist/data/t10k-images-idx3-ubyte.gz
# Extracting ./mnist/data/t10k-labels-idx1-ubyte.gz

# %%
import tensorflow as tf
import numpy as np
import os, sys
import matplotlib.pyplot as plt

from model import Attacker

# %matplotlib inline


sess = tf.Session()
batch_x, batch_y = mnist.train.images[:2], mnist.train.labels[:2]
target = np.where(batch_y[0] == 1)[0][0]
print(target)
QEattack = Attacker(sess, target_label = target)
plt.imshow(np.reshape(batch_x[0], (28, 28)), cmap=plt.get_cmap('gray'))
plt.show()
plt.imshow(np.reshape(batch_x[1], (28, 28)), cmap=plt.get_cmap('gray'))
plt.show()

# make X looks like X_tar while maintaining the label
QEattack.attack(batch_x[0], batch_x[1])
# Out:
# 7
# INFO:tensorflow:Restoring parameters from ./checkpoints/mnist_cnn_weight.ckpt
# Query: 0, Epsilon: 0.4950000047683716, Rank: 1
# 24330.953
# Query: 10, Epsilon: 0.4802980422973633, Rank: 0
# 40282.227
# Query: 20, Epsilon: 0.4660327136516571, Rank: 0
# 53010.715
# Query: 30, Epsilon: 0.4476691782474518, Rank: 1
# 14508.781
# Query: 40, Epsilon: 0.4343729615211487, Rank: 0
# 48651.453
# Query: 50, Epsilon: 0.42147165536880493, Rank: 1
# 49499.05
# Query: 60, Epsilon: 0.40486401319503784, Rank: 2
# 16983.773
# Query: 70, Epsilon: 0.3928391635417938, Rank: 1
# 33652.75
# Query: 80, Epsilon: 0.38117143511772156, Rank: 1
# 38680.652
# Query: 90, Epsilon: 0.36615175008773804, Rank: 3
# 7580.981
# Query: 100, Epsilon: 0.358865350484848, Rank: 1
# 50163.29
# Query: 110, Epsilon: 0.3447246253490448, Rank: 0
# 59950.88
# Query: 120, Epsilon: 0.3311411142349243, Rank: 1
# 39851.45
# Query: 130, Epsilon: 0.32130593061447144, Rank: 1
# 38246.22
# Query: 140, Epsilon: 0.31176283955574036, Rank: 1
# 35203.645
# Query: 150, Epsilon: 0.30250319838523865, Rank: 1
# 22603.465
# Query: 160, Epsilon: 0.29058340191841125, Rank: 1
# 17137.572
# Query: 170, Epsilon: 0.28480079770088196, Rank: 0
# 59324.754
# Query: 180, Epsilon: 0.2708427309989929, Rank: 3
# 7339.809
# Query: 190, Epsilon: 0.2627984285354614, Rank: 1
# 21834.25
# Query: 200, Epsilon: 0.2549930512905121, Rank: 1
# 30565.498
# Query: 210, Epsilon: 0.24741952121257782, Rank: 2
# 14802.9375
# Query: 220, Epsilon: 0.23767021298408508, Rank: 1
# 29221.512
# Query: 230, Epsilon: 0.22830505669116974, Rank: 0
# 39351.637
# Query: 240, Epsilon: 0.2215241640806198, Rank: 1
# 16745.076
# Query: 250, Epsilon: 0.21494467556476593, Rank: 2
# 6951.9634
# Query: 260, Epsilon: 0.20856061577796936, Rank: 2
# 8340.074
# Query: 270, Epsilon: 0.2023661583662033, Rank: 1
# 20956.27
# Query: 280, Epsilon: 0.1963556855916977, Rank: 1
# 16435.357
# Query: 290, Epsilon: 0.19052372872829437, Rank: 0
# 64209.766
# Query: 300, Epsilon: 0.1830163300037384, Rank: 1
# 34174.57
# Query: 310, Epsilon: 0.1775805652141571, Rank: 0
# 62148.555
# Query: 320, Epsilon: 0.17058318853378296, Rank: 2
# 15423.266
# Query: 330, Epsilon: 0.16386154294013977, Rank: 1
# 30596.965
# Query: 340, Epsilon: 0.1606006920337677, Rank: 0
# 63804.184
