# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("./mnist/data/", one_hot=True)
# Out:
# Extracting ./mnist/data/train-images-idx3-ubyte.gz
# Extracting ./mnist/data/train-labels-idx1-ubyte.gz
# Extracting ./mnist/data/t10k-images-idx3-ubyte.gz
# Extracting ./mnist/data/t10k-labels-idx1-ubyte.gz

# %%
import tensorflow as tf
import numpy as np
import os, sys
import matplotlib.pyplot as plt

from model import Attacker

# %matplotlib inline


sess = tf.Session()
batch_x, batch_y = mnist.train.images[:2], mnist.train.labels[:2]
target = np.where(batch_y[0] == 1)[0][0]
print(target)
QEattack = Attacker(sess, target_label = target)
plt.imshow(np.reshape(batch_x[0], (28, 28)), cmap=plt.get_cmap('gray'))
plt.show()
plt.imshow(np.reshape(batch_x[1], (28, 28)), cmap=plt.get_cmap('gray'))
plt.show()

# make X looks like X_tar while maintaining the label
QEattack.attack(batch_x[0], batch_x[1])
# Out:
# 7
# INFO:tensorflow:Restoring parameters from ./checkpoints/mnist_cnn_weight.ckpt
# Query: 0, Epsilon: 0.4950000047683716, Rank: 1
# 46801.086
# Query: 10, Epsilon: 0.5, Rank: 1
# 35627.44
# Query: 20, Epsilon: 0.5, Rank: 1
# 22559.5
# Query: 30, Epsilon: 0.5, Rank: 0
# 58030.52
# Query: 40, Epsilon: 0.5, Rank: 1
# 21606.11
# Query: 50, Epsilon: 0.5, Rank: 0
# 39416.76
# Query: 60, Epsilon: 0.5, Rank: 1
# 54858.64
# Query: 70, Epsilon: 0.5, Rank: 1
# 37086.156
# Query: 80, Epsilon: 0.5, Rank: 1
# 31619.393
# Query: 90, Epsilon: 0.5, Rank: 1
# 55895.67
# Query: 100, Epsilon: 0.5, Rank: 1
# 41858.57
# Query: 110, Epsilon: 0.5, Rank: 0
# 53384.5
# Query: 120, Epsilon: 0.495, Rank: 2
# 13615.633
# Query: 130, Epsilon: 0.5, Rank: 1
# 34831.605
# Query: 140, Epsilon: 0.495, Rank: 1
# 16544.678
# Query: 150, Epsilon: 0.5, Rank: 1
# 43986.543
# Query: 160, Epsilon: 0.5, Rank: 1
# 42366.832
# Query: 170, Epsilon: 0.5, Rank: 1
# 30604.97
# Query: 180, Epsilon: 0.5, Rank: 1
# 36617.45
# ...
