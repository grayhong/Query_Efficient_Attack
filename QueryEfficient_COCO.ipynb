# %%
from scipy.misc import imread, imresize

directory = "./vgg/train2014"

# %%
import tensorflow as tf
import numpy as np
import os, sys
import matplotlib.pyplot as plt

from model_cifar10 import Attacker

# %matplotlib inline


sess = tf.Session()
batch_x, batch_y = test_x[:2], test_y[:2]
target = np.where(batch_y[0] == 1)[0][0]
QEattack = Attacker(sess, target_label = target)
plt.imshow(np.reshape(batch_x[0], (32, 32, 3)))
plt.show()
plt.imshow(np.reshape(batch_x[1], (32, 32, 3)))
plt.show()

# make X looks like X_tar while maintaining the label
QEattack.attack(batch_x[0], batch_x[1])
# Out:
# INFO:tensorflow:Summary name Fully connected layers/fc1 is illegal; using Fully_connected_layers/fc1 instead.
# INFO:tensorflow:Summary name Fully connected layers/fc1 is illegal; using Fully_connected_layers/fc1 instead.
# INFO:tensorflow:Summary name Fully connected layers/fc2 is illegal; using Fully_connected_layers/fc2 instead.
# INFO:tensorflow:Summary name Fully connected layers/fc2 is illegal; using Fully_connected_layers/fc2 instead.
# INFO:tensorflow:Summary name Fully connected layers/output is illegal; using Fully_connected_layers/output instead.
# WARNING:tensorflow:From /home/mlilab/Query_Efficient_Attack/cifar10/include/model.py:186: calling argmax (from tensorflow.python.ops.math_ops) with dimension is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the `axis` argument instead
# INFO:tensorflow:Restoring parameters from ./cifar10/tensorboard/cifar-10/-12300
# Query: 0, Epsilon: 0.30735686772502346, Rank: 1
# 0.5965361
# Query: 1, Epsilon: 0.27738957312183365, Rank: 1
# -0.1649072
# Query: 2, Epsilon: 0.263520094465742, Rank: 1
# -1.1059202
# Query: 3, Epsilon: 0.25034408974245487, Rank: 2
# -1.0450221
# Query: 4, Epsilon: 0.25034408974245487, Rank: 1
# 0.7879706
# Query: 5, Epsilon: 0.2378268852553321, Rank: 2
# 0.364623
# Query: 6, Epsilon: 0.2378268852553321, Rank: 1
# 0.70751
# Query: 7, Epsilon: 0.2259355409925655, Rank: 1
# 0.55729717
# Query: 8, Epsilon: 0.2146387639429372, Rank: 1
# 0.82357454
# Query: 9, Epsilon: 0.20390682574579033, Rank: 3
# -3.0335288
# Query: 10, Epsilon: 0.20390682574579033, Rank: 2
# -1.5925539
# Query: 11, Epsilon: 0.20390682574579033, Rank: 1
# 0.097078525
# Query: 12, Epsilon: 0.1937114844585008, Rank: 2
# -1.5654013
